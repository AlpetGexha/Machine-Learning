# %%
import pandas as pd

# %%
data = pd.read_csv("nba.csv")

# %%
data.head()
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2   John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3    R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4  Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
#
#              College     Salary
# 0              Texas  7730337.0
# 1          Marquette  6796117.0
# 2  Boston University        NaN
# 3      Georgia State  1148640.0
# 4                NaN  5000000.0

# %%
data.shape
# Out:
# (457, 9)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 457 entries, 0 to 456
# Data columns (total 9 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Name      457 non-null    object
#  1   Team      457 non-null    object
#  2   Number    457 non-null    float64
#  3   Position  457 non-null    object
#  4   Age       457 non-null    float64
#  5   Height    457 non-null    object
#  6   Weight    457 non-null    float64
#  7   College   373 non-null    object
#  8   Salary    446 non-null    float64
# dtypes: float64(4), object(5)
# memory usage: 32.3+ KB

# %%
data.values
# Out:
# array([['Avery Bradley', 'Boston Celtics', 0.0, ..., 180.0, 'Texas',
#         7730337.0],
#        ['Jae Crowder', 'Boston Celtics', 99.0, ..., 235.0, 'Marquette',
#         6796117.0],
#        ['John Holland', 'Boston Celtics', 30.0, ..., 205.0,
#         'Boston University', nan],
#        ...,
#        ['Raul Neto', 'Utah Jazz', 25.0, ..., 179.0, nan, 900000.0],
#        ['Tibor Pleiss', 'Utah Jazz', 21.0, ..., 256.0, nan, 2900000.0],
#        ['Jeff Withey', 'Utah Jazz', 24.0, ..., 231.0, 'Kansas', 947276.0]],
#       dtype=object)

# %%
data.columns
# Out:
# Index(['Name', 'Team', 'Number', 'Position', 'Age', 'Height', 'Weight',
#        'College', 'Salary'],
#       dtype='object')

# %%
data.index
# Out:
# RangeIndex(start=0, stop=457, step=1)

# %%
# rendit te dhenat ne myre qe te lexoj 5 lojater me pak te paguar
min_salary = data.sort_values("Salary")
min_salary=min_salary.head()
min_salary
# Out:
#                        Name                  Team  Number Position   Age  \
# 32   Thanasis Antetokounmpo       New York Knicks    43.0       SF  23.0
# 291         Orlando Johnson  New Orleans Pelicans     0.0       SG  27.0
# 130            Phil Pressey          Phoenix Suns    25.0       PG  25.0
# 135           Alan Williams          Phoenix Suns    15.0        C  23.0
# 175            Jordan McRae   Cleveland Cavaliers    12.0       SG  25.0
#
#     Height  Weight           College    Salary
# 32     6-7   205.0               NaN   30888.0
# 291    6-5   220.0  UC Santa Barbara   55722.0
# 130   5-11   175.0          Missouri   55722.0
# 135    6-8   260.0  UC Santa Barbara   83397.0
# 175    6-5   179.0         Tennessee  111196.0

# %%
# rendit te dhenat ne myre qe te lexoj 5 lojater me shume te paguar
max_salary = data.sort_values("Salary", ascending=False)
max_salary=max_salary.head()
max_salary
# Out:
#                 Name                 Team  Number Position   Age Height  \
# 109      Kobe Bryant   Los Angeles Lakers    24.0       SF  37.0    6-6
# 169     LeBron James  Cleveland Cavaliers    23.0       SF  31.0    6-8
# 33   Carmelo Anthony      New York Knicks     7.0       SF  32.0    6-8
# 251    Dwight Howard      Houston Rockets    12.0        C  30.0   6-11
# 339       Chris Bosh           Miami Heat     1.0       PF  32.0   6-11
#
#      Weight       College      Salary
# 109   212.0           NaN  25000000.0
# 169   250.0           NaN  22970500.0
# 33    240.0      Syracuse  22875000.0
# 251   265.0           NaN  22359364.0
# 339   235.0  Georgia Tech  22192730.0

# %%
data_pos_sal = data.sort_values(['Position','Salary'], ascending=[True, False])
data_pos_sal
# Out:
#                 Name                  Team  Number Position   Age Height  \
# 251    Dwight Howard       Houston Rockets    12.0        C  30.0   6-11
# 23       Brook Lopez         Brooklyn Nets    11.0        C  28.0    7-0
# 98    DeAndre Jordan  Los Angeles Clippers     6.0        C  27.0   6-11
# 265       Marc Gasol     Memphis Grizzlies    33.0        C  31.0    7-1
# 220      Greg Monroe       Milwaukee Bucks    15.0        C  26.0   6-11
# ..               ...                   ...     ...      ...   ...    ...
# 175     Jordan McRae   Cleveland Cavaliers    12.0       SG  25.0    6-5
# 291  Orlando Johnson  New Orleans Pelicans     0.0       SG  27.0    6-5
# 2       John Holland        Boston Celtics    30.0       SG  27.0    6-5
# 171    Dahntay Jones   Cleveland Cavaliers    30.0       SG  35.0    6-6
# 397     Axel Toupane        Denver Nuggets     6.0       SG  23.0    6-7
#
#      Weight            College      Salary
# 251   265.0                NaN  22359364.0
# ...

# %%
# ndertoj nje dataframe duke mare vetem dy kolona
data.to_csv("pos_sal.csv", columns=["Position", "Salary"])

# %%
# pjese nga rreshtat
post_c = data[data['Position']=='C']
post_c.head()
# Out:
#                Name            Team  Number Position   Age Height  Weight  \
# 7      Kelly Olynyk  Boston Celtics    41.0        C  25.0    7-0   238.0
# 10  Jared Sullinger  Boston Celtics     7.0        C  24.0    6-9   260.0
# 14     Tyler Zeller  Boston Celtics    44.0        C  26.0    7-0   253.0
# 23      Brook Lopez   Brooklyn Nets    11.0        C  28.0    7-0   275.0
# 27       Henry Sims   Brooklyn Nets    14.0        C  26.0   6-10   248.0
#
#            College      Salary
# 7          Gonzaga   2165160.0
# 10      Ohio State   2569260.0
# 14  North Carolina   2616975.0
# 23        Stanford  19689000.0
# 27      Georgetown    947276.0

# %%
post_c.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 78 entries, 7 to 456
# Data columns (total 9 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Name      78 non-null     object
#  1   Team      78 non-null     object
#  2   Number    78 non-null     float64
#  3   Position  78 non-null     object
#  4   Age       78 non-null     float64
#  5   Height    78 non-null     object
#  6   Weight    78 non-null     float64
#  7   College   49 non-null     object
#  8   Salary    78 non-null     float64
# dtypes: float64(4), object(5)
# memory usage: 6.1+ KB

# %%
post_c.tail()
# Out:
#               Name                    Team  Number Position   Age Height  \
# 434    Chris Kaman  Portland Trail Blazers    35.0        C  34.0    7-0
# 439  Mason Plumlee  Portland Trail Blazers    24.0        C  26.0   6-11
# 447    Rudy Gobert               Utah Jazz    27.0        C  23.0    7-1
# 455   Tibor Pleiss               Utah Jazz    21.0        C  26.0    7-3
# 456    Jeff Withey               Utah Jazz    24.0        C  26.0    7-0
#
#      Weight           College     Salary
# 434   265.0  Central Michigan  5016000.0
# 439   235.0              Duke  1415520.0
# 447   245.0               NaN  1175880.0
# 455   256.0               NaN  2900000.0
# 456   231.0            Kansas   947276.0

# %%
data['Name_Team'] = data['Name'] + ": " + data['Team']
data.head()
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2   John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3    R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4  Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
#
#              College     Salary                      Name_Team
# 0              Texas  7730337.0  Avery Bradley: Boston Celtics
# 1          Marquette  6796117.0    Jae Crowder: Boston Celtics
# 2  Boston University        NaN   John Holland: Boston Celtics
# 3      Georgia State  1148640.0    R.J. Hunter: Boston Celtics
# 4                NaN  5000000.0  Jonas Jerebko: Boston Celtics

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 457 entries, 0 to 456
# Data columns (total 10 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Name       457 non-null    object
#  1   Team       457 non-null    object
#  2   Number     457 non-null    float64
#  3   Position   457 non-null    object
#  4   Age        457 non-null    float64
#  5   Height     457 non-null    object
#  6   Weight     457 non-null    float64
#  7   College    373 non-null    object
#  8   Salary     446 non-null    float64
#  9   Name_Team  457 non-null    object
# dtypes: float64(4), object(6)
# memory usage: 35.8+ KB

# %%
data.describe()
# Out:
#            Number         Age      Weight        Salary
# count  457.000000  457.000000  457.000000  4.460000e+02
# mean    17.678337   26.938731  221.522976  4.842684e+06
# std     15.966090    4.404016   26.368343  5.229238e+06
# min      0.000000   19.000000  161.000000  3.088800e+04
# 25%      5.000000   24.000000  200.000000  1.044792e+06
# 50%     13.000000   26.000000  220.000000  2.839073e+06
# 75%     25.000000   30.000000  240.000000  6.500000e+06
# max     99.000000   40.000000  307.000000  2.500000e+07

# %%
mean_age = data['Age'].mean()
mean_age
# Out:
# 26.938730853391686

# %%
data['Age'].max()
# Out:
# 40.0

# %%
mean_salary = data['Salary'].mean()
data['Salary'].fillna(mean_salary, inplace=True)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 457 entries, 0 to 456
# Data columns (total 10 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Name       457 non-null    object
#  1   Team       457 non-null    object
#  2   Number     457 non-null    float64
#  3   Position   457 non-null    object
#  4   Age        457 non-null    float64
#  5   Height     457 non-null    object
#  6   Weight     457 non-null    float64
#  7   College    373 non-null    object
#  8   Salary     457 non-null    float64
#  9   Name_Team  457 non-null    object
# dtypes: float64(4), object(6)
# memory usage: 35.8+ KB

# %%
data.describe()
# Out:
#            Number         Age      Weight        Salary
# count  457.000000  457.000000  457.000000  4.570000e+02
# mean    17.678337   26.938731  221.522976  4.842684e+06
# std     15.966090    4.404016   26.368343  5.165781e+06
# min      0.000000   19.000000  161.000000  3.088800e+04
# 25%      5.000000   24.000000  200.000000  1.100602e+06
# 50%     13.000000   26.000000  220.000000  2.869440e+06
# 75%     25.000000   30.000000  240.000000  6.331404e+06
# max     99.000000   40.000000  307.000000  2.500000e+07

# %%
data.dropna()
# Out:
#               Name            Team  Number Position   Age Height  Weight  \
# 0    Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1      Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2     John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3      R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 6    Jordan Mickey  Boston Celtics    55.0       PF  21.0    6-8   235.0
# ..             ...             ...     ...      ...   ...    ...     ...
# 449    Rodney Hood       Utah Jazz     5.0       SG  23.0    6-8   206.0
# 451  Chris Johnson       Utah Jazz    23.0       SF  26.0    6-6   206.0
# 452     Trey Lyles       Utah Jazz    41.0       PF  20.0   6-10   234.0
# 453   Shelvin Mack       Utah Jazz     8.0       PG  26.0    6-3   203.0
# 456    Jeff Withey       Utah Jazz    24.0        C  26.0    7-0   231.0
#
#                College        Salary                      Name_Team
# ...

# %%
data.drop_duplicates(inplace=True, keep='first')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 457 entries, 0 to 456
# Data columns (total 10 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Name       457 non-null    object
#  1   Team       457 non-null    object
#  2   Number     457 non-null    float64
#  3   Position   457 non-null    object
#  4   Age        457 non-null    float64
#  5   Height     457 non-null    object
#  6   Weight     457 non-null    float64
#  7   College    373 non-null    object
#  8   Salary     457 non-null    float64
#  9   Name_Team  457 non-null    object
# dtypes: float64(4), object(6)
# memory usage: 35.8+ KB
