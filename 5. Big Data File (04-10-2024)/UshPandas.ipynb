# %%
studentet = {
    "emri":["Teuta","Altin", "Blerina ", "Donat","Nderim","Sara"],
    "mbiemri":["Shala","Nimani", "Tahiraj", "Imeri", "Ajdari","Kicaj"],
    "kursi" : ["Big Data", "Python", "ML", "AI", "AI", "ML"],
    "mosha":[22, 24, 26, 28,22,24],
    "email":["teuta@gmail.com", "altin@gmail.com", "blerina@gmail.com", "donat@gmail.com","nderim@gmail.com","sara@gmail.com"],
    "nota": [8, 9, 5, 6,10,8]
}

# %%
import pandas as pd
dataframe = pd.DataFrame(studentet)

# %%
dataframe
# Out:
#        emri  mbiemri     kursi  mosha              email  nota
# 0     Teuta    Shala  Big Data     22    teuta@gmail.com     8
# 1     Altin   Nimani    Python     24    altin@gmail.com     9
# 2  Blerina   Tahiraj        ML     26  blerina@gmail.com     5
# 3     Donat    Imeri        AI     28    donat@gmail.com     6
# 4    Nderim   Ajdari        AI     22   nderim@gmail.com    10
# 5      Sara    Kicaj        ML     24     sara@gmail.com     8

# %%
dataframe.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6 entries, 0 to 5
# Data columns (total 6 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   emri     6 non-null      object
#  1   mbiemri  6 non-null      object
#  2   kursi    6 non-null      object
#  3   mosha    6 non-null      int64
#  4   email    6 non-null      object
#  5   nota     6 non-null      int64
# dtypes: int64(2), object(4)
# memory usage: 420.0+ bytes

# %%
dataframe.columns
# Out:
# Index(['emri', 'mbiemri', 'kursi', 'mosha', 'email', 'nota'], dtype='object')

# %%
# modifikoj emrat e kolonave
dataframe.columns = ['emri_std', 'mbiemri_std', 'kursi_std', 'mosha_std', 'email_std', 'nota_std']

# %%
dataframe.columns
# Out:
# Index(['emri_std', 'mbiemri_std', 'kursi_std', 'mosha_std', 'email_std',
#        'nota_std'],
#       dtype='object')

# %%
dataframe.columns = [x.upper() for x in dataframe.columns]

# %%
dataframe
# Out:
#    EMRI_STD MBIEMRI_STD KURSI_STD  MOSHA_STD          EMAIL_STD  NOTA_STD
# 0     Teuta       Shala  Big Data         22    teuta@gmail.com         8
# 1     Altin      Nimani    Python         24    altin@gmail.com         9
# 2  Blerina      Tahiraj        ML         26  blerina@gmail.com         5
# 3     Donat       Imeri        AI         28    donat@gmail.com         6
# 4    Nderim      Ajdari        AI         22   nderim@gmail.com        10
# 5      Sara       Kicaj        ML         24     sara@gmail.com         8

# %%
dataframe.columns = [x.lower() for x in dataframe.columns]

# %%
dataframe
# Out:
#    emri_std mbiemri_std kursi_std  mosha_std          email_std  nota_std
# 0     Teuta       Shala  Big Data         22    teuta@gmail.com         8
# 1     Altin      Nimani    Python         24    altin@gmail.com         9
# 2  Blerina      Tahiraj        ML         26  blerina@gmail.com         5
# 3     Donat       Imeri        AI         28    donat@gmail.com         6
# 4    Nderim      Ajdari        AI         22   nderim@gmail.com        10
# 5      Sara       Kicaj        ML         24     sara@gmail.com         8

# %%
# update nje kolone specifike
dataframe.rename(columns={"emri_std": "emri"}, inplace=True)
dataframe
# Out:
#        emri mbiemri_std kursi_std  mosha_std          email_std  nota_std
# 0     Teuta       Shala  Big Data         22    teuta@gmail.com         8
# 1     Altin      Nimani    Python         24    altin@gmail.com         9
# 2  Blerina      Tahiraj        ML         26  blerina@gmail.com         5
# 3     Donat       Imeri        AI         28    donat@gmail.com         6
# 4    Nderim      Ajdari        AI         22   nderim@gmail.com        10
# 5      Sara       Kicaj        ML         24     sara@gmail.com         8

# %%
dataframe.loc[3]
# Out:
# emri                     Donat
# mbiemri_std              Imeri
# kursi_std                   AI
# mosha_std                   28
# email_std      donat@gmail.com
# nota_std                     6
# Name: 3, dtype: object

# %%
dataframe.loc[3] = ["Freda", "Dyrkaj", "ML", 35, "freda@gmail.com", 7]

# %%
dataframe
# Out:
#        emri mbiemri_std kursi_std  mosha_std          email_std  nota_std
# 0     Teuta       Shala  Big Data         22    teuta@gmail.com         8
# 1     Altin      Nimani    Python         24    altin@gmail.com         9
# 2  Blerina      Tahiraj        ML         26  blerina@gmail.com         5
# 3     Freda      Dyrkaj        ML         35    freda@gmail.com         7
# 4    Nderim      Ajdari        AI         22   nderim@gmail.com        10
# 5      Sara       Kicaj        ML         24     sara@gmail.com         8

# %%
dataframe.loc[2, "email_std"] = "blerina111@gmail.com"
dataframe
# Out:
#        emri mbiemri_std kursi_std  mosha_std             email_std  nota_std
# 0     Teuta       Shala  Big Data         22       teuta@gmail.com         8
# 1     Altin      Nimani    Python         24       altin@gmail.com         9
# 2  Blerina      Tahiraj        ML         26  blerina111@gmail.com         5
# 3     Freda      Dyrkaj        ML         35       freda@gmail.com         7
# 4    Nderim      Ajdari        AI         22      nderim@gmail.com        10
# 5      Sara       Kicaj        ML         24        sara@gmail.com         8

# %%
dataframe.loc[2, ["email_std","nota_std"]] = ["blerina@gmail.com",9]
dataframe
# Out:
#        emri mbiemri_std kursi_std  mosha_std          email_std  nota_std
# 0     Teuta       Shala  Big Data         22    teuta@gmail.com         8
# 1     Altin      Nimani    Python         24    altin@gmail.com         9
# 2  Blerina      Tahiraj        ML         26  blerina@gmail.com         9
# 3     Freda      Dyrkaj        ML         35    freda@gmail.com         7
# 4    Nderim      Ajdari        AI         22   nderim@gmail.com        10
# 5      Sara       Kicaj        ML         24     sara@gmail.com         8

# %%
# ndryshoj emailin e std me mbiemer dyrkaj
filt_mbiemri = (dataframe["mbiemri_std"]=="Dyrkaj")
filt_mbiemri
# Out:
# 0    False
# 1    False
# 2    False
# 3     True
# 4    False
# 5    False
# Name: mbiemri_std, dtype: bool

# %%
dataframe.loc[filt_mbiemri, 'email_std'] = "freda111@gmail.com"
dataframe
# Out:
#        emri mbiemri_std kursi_std  mosha_std           email_std  nota_std
# 0     Teuta       Shala  Big Data         22     teuta@gmail.com         8
# 1     Altin      Nimani    Python         24     altin@gmail.com         9
# 2  Blerina      Tahiraj        ML         26   blerina@gmail.com         9
# 3     Freda      Dyrkaj        ML         35  freda111@gmail.com         7
# 4    Nderim      Ajdari        AI         22    nderim@gmail.com        10
# 5      Sara       Kicaj        ML         24      sara@gmail.com         8

# %%
# metoda lower tek vlerat e rreshtave
dataframe["kursi_std"] = dataframe['kursi_std'].str.lower()
dataframe
# Out:
#        emri mbiemri_std kursi_std  mosha_std           email_std  nota_std
# 0     Teuta       Shala  big data         22     teuta@gmail.com         8
# 1     Altin      Nimani    python         24     altin@gmail.com         9
# 2  Blerina      Tahiraj        ml         26   blerina@gmail.com         9
# 3     Freda      Dyrkaj        ml         35  freda111@gmail.com         7
# 4    Nderim      Ajdari        ai         22    nderim@gmail.com        10
# 5      Sara       Kicaj        ml         24      sara@gmail.com         8

# %%
dataframe["kursi_std"] = dataframe['kursi_std'].str.capitalize()
dataframe
# Out:
#        emri mbiemri_std kursi_std  mosha_std           email_std  nota_std
# 0     Teuta       Shala  Big data         22     teuta@gmail.com         8
# 1     Altin      Nimani    Python         24     altin@gmail.com         9
# 2  Blerina      Tahiraj        Ml         26   blerina@gmail.com         9
# 3     Freda      Dyrkaj        Ml         35  freda111@gmail.com         7
# 4    Nderim      Ajdari        Ai         22    nderim@gmail.com        10
# 5      Sara       Kicaj        Ml         24      sara@gmail.com         8

# %%
# apply ndihmon ne aplikimin e funksioneve ne te dhenat e df
# funksion built in=len
dataframe['email_std'].apply(len)
# Out:
# 0    15
# 1    15
# 2    17
# 3    18
# 4    16
# 5    14
# Name: email_std, dtype: int64

# %%
# funksion te dnertuar nga ne
def upd_emri(emri):
    return emri.upper()

dataframe['emri'] = dataframe['emri'].apply(upd_emri)

# %%
dataframe
# Out:
#        emri mbiemri_std kursi_std  mosha_std           email_std  nota_std
# 0     TEUTA       Shala  Big data         22     teuta@gmail.com         8
# 1     ALTIN      Nimani    Python         24     altin@gmail.com         9
# 2  BLERINA      Tahiraj        Ml         26   blerina@gmail.com         9
# 3     FREDA      Dyrkaj        Ml         35  freda111@gmail.com         7
# 4    NDERIM      Ajdari        Ai         22    nderim@gmail.com        10
# 5      SARA       Kicaj        Ml         24      sara@gmail.com         8

# %%
# shtojme nje kolone
dataframe['emer_mb'] = dataframe['emri'] + " " + dataframe['mbiemri_std']
dataframe
# Out:
#        emri mbiemri_std kursi_std  mosha_std           email_std  nota_std  \
# 0     TEUTA       Shala  Big data         22     teuta@gmail.com         8
# 1     ALTIN      Nimani    Python         24     altin@gmail.com         9
# 2  BLERINA      Tahiraj        Ml         26   blerina@gmail.com         9
# 3     FREDA      Dyrkaj        Ml         35  freda111@gmail.com         7
# 4    NDERIM      Ajdari        Ai         22    nderim@gmail.com        10
# 5      SARA       Kicaj        Ml         24      sara@gmail.com         8
#
#             emer_mb
# 0       TEUTA Shala
# 1      ALTIN Nimani
# 2  BLERINA  Tahiraj
# 3      FREDA Dyrkaj
# 4     NDERIM Ajdari
# 5        SARA Kicaj

# %%
dataframe.drop(columns = ['emer_mb'], inplace=True)

# %%
dataframe
# Out:
#        emri mbiemri_std kursi_std  mosha_std           email_std  nota_std
# 0     TEUTA       Shala  Big data         22     teuta@gmail.com         8
# 1     ALTIN      Nimani    Python         24     altin@gmail.com         9
# 2  BLERINA      Tahiraj        Ml         26   blerina@gmail.com         9
# 3     FREDA      Dyrkaj        Ml         35  freda111@gmail.com         7
# 4    NDERIM      Ajdari        Ai         22    nderim@gmail.com        10
# 5      SARA       Kicaj        Ml         24      sara@gmail.com         8

# %%
dataframe[["username", "domain"]] = dataframe['email_std'].str.split("@", expand=True)
dataframe
# Out:
#        emri mbiemri_std kursi_std  mosha_std           email_std  nota_std  \
# 0     TEUTA       Shala  Big data         22     teuta@gmail.com         8
# 1     ALTIN      Nimani    Python         24     altin@gmail.com         9
# 2  BLERINA      Tahiraj        Ml         26   blerina@gmail.com         9
# 3     FREDA      Dyrkaj        Ml         35  freda111@gmail.com         7
# 4    NDERIM      Ajdari        Ai         22    nderim@gmail.com        10
# 5      SARA       Kicaj        Ml         24      sara@gmail.com         8
#
#    username     domain
# 0     teuta  gmail.com
# 1     altin  gmail.com
# 2   blerina  gmail.com
# 3  freda111  gmail.com
# 4    nderim  gmail.com
# 5      sara  gmail.com

# %%
# fshirja e rreshtave
# dataframe.drop(index = [1,2], inplace=True)
dataframe = dataframe.reset_index()
dataframe
# Out:
#    level_0  index    emri mbiemri_std kursi_std  mosha_std  \
# 0        0      0   TEUTA       Shala  Big data         22
# 1        1      3   FREDA      Dyrkaj        Ml         35
# 2        2      4  NDERIM      Ajdari        Ai         22
# 3        3      5    SARA       Kicaj        Ml         24
#
#             email_std  nota_std  username     domain
# 0     teuta@gmail.com         8     teuta  gmail.com
# 1  freda111@gmail.com         7  freda111  gmail.com
# 2    nderim@gmail.com        10    nderim  gmail.com
# 3      sara@gmail.com         8      sara  gmail.com

# %%
dataframe.drop(columns = ["level_0", 'index'], inplace=True)
dataframe
# Out:
#      emri mbiemri_std kursi_std  mosha_std           email_std  nota_std  \
# 0   TEUTA       Shala  Big data         22     teuta@gmail.com         8
# 1   FREDA      Dyrkaj        Ml         35  freda111@gmail.com         7
# 2  NDERIM      Ajdari        Ai         22    nderim@gmail.com        10
# 3    SARA       Kicaj        Ml         24      sara@gmail.com         8
#
#    username     domain
# 0     teuta  gmail.com
# 1  freda111  gmail.com
# 2    nderim  gmail.com
# 3      sara  gmail.com
