# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sb

# %%
# importimin e datasetit
dataseti = pd.read_csv('dataseti.csv')

# %%
dataseti.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1292954 entries, 0 to 1292953
# Data columns (total 7 columns):
#  #   Column      Non-Null Count    Dtype
# ---  ------      --------------    -----
#  0   item_id     1292954 non-null  int64
#  1   user_id     1292954 non-null  int64
#  2   rating      1292954 non-null  float64
#  3   timestamp   1292954 non-null  object
#  4   model_attr  1292954 non-null  object
#  5   category    1292954 non-null  object
#  6   brand       331120 non-null   object
# dtypes: float64(1), int64(2), object(4)
# memory usage: 69.1+ MB

# %%
dataseti.head()
# Out:
#    item_id  user_id  rating   timestamp model_attr                category  \
# 0        0        0     5.0  1999-06-13     Female  Portable Audio & Video
# 1        0        1     5.0  1999-06-14     Female  Portable Audio & Video
# 2        0        2     3.0  1999-06-17     Female  Portable Audio & Video
# 3        0        3     1.0  1999-07-01     Female  Portable Audio & Video
# 4        0        4     2.0  1999-07-06     Female  Portable Audio & Video
#
#   brand
# 0   NaN
# 1   NaN
# 2   NaN
# 3   NaN
# 4   NaN

# %%
dataseti.drop_duplicates()
# Out:
#          item_id  user_id  rating   timestamp model_attr  \
# 0              0        0     5.0  1999-06-13     Female
# 1              0        1     5.0  1999-06-14     Female
# 2              0        2     3.0  1999-06-17     Female
# 3              0        3     1.0  1999-07-01     Female
# 4              0        4     2.0  1999-07-06     Female
# ...          ...      ...     ...         ...        ...
# 1292949     9478  1157628     1.0  2018-09-26     Female
# 1292950     9435  1157629     5.0  2018-09-26     Female
# 1292951     9305  1157630     3.0  2018-09-26     Female
# 1292952     9303  1157631     5.0  2018-09-29       Male
# 1292953     9478  1157632     1.0  2018-10-01     Female
#
#                         category       brand
# 0         Portable Audio & Video         NaN
# 1         Portable Audio & Video         NaN
# 2         Portable Audio & Video         NaN
# 3         Portable Audio & Video         NaN
# 4         Portable Audio & Video         NaN
# ...

# %%
dataseti.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1292954 entries, 0 to 1292953
# Data columns (total 7 columns):
#  #   Column      Non-Null Count    Dtype
# ---  ------      --------------    -----
#  0   item_id     1292954 non-null  int64
#  1   user_id     1292954 non-null  int64
#  2   rating      1292954 non-null  float64
#  3   timestamp   1292954 non-null  object
#  4   model_attr  1292954 non-null  object
#  5   category    1292954 non-null  object
#  6   brand       331120 non-null   object
# dtypes: float64(1), int64(2), object(4)
# memory usage: 69.1+ MB

# %%
# kthej kolone timestamp ne nje datetime
from datetime import datetime

dataseti['timestamp']=pd.to_datetime(dataseti['timestamp'])

# %%
dataseti.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1292954 entries, 0 to 1292953
# Data columns (total 7 columns):
#  #   Column      Non-Null Count    Dtype
# ---  ------      --------------    -----
#  0   item_id     1292954 non-null  int64
#  1   user_id     1292954 non-null  int64
#  2   rating      1292954 non-null  float64
#  3   timestamp   1292954 non-null  datetime64[ns]
#  4   model_attr  1292954 non-null  object
#  5   category    1292954 non-null  object
#  6   brand       331120 non-null   object
# dtypes: datetime64[ns](1), float64(1), int64(2), object(3)
# memory usage: 69.1+ MB

# %%
dataseti['year'] = pd.DatetimeIndex(dataseti['timestamp']).year

# %%
dataseti.head()
# Out:
#    item_id  user_id  rating  timestamp model_attr                category  \
# 0        0        0     5.0 1999-06-13     Female  Portable Audio & Video
# 1        0        1     5.0 1999-06-14     Female  Portable Audio & Video
# 2        0        2     3.0 1999-06-17     Female  Portable Audio & Video
# 3        0        3     1.0 1999-07-01     Female  Portable Audio & Video
# 4        0        4     2.0 1999-07-06     Female  Portable Audio & Video
#
#   brand  year
# 0   NaN  1999
# 1   NaN  1999
# 2   NaN  1999
# 3   NaN  1999
# 4   NaN  1999

# %%
dataseti.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1292954 entries, 0 to 1292953
# Data columns (total 8 columns):
#  #   Column      Non-Null Count    Dtype
# ---  ------      --------------    -----
#  0   item_id     1292954 non-null  int64
#  1   user_id     1292954 non-null  int64
#  2   rating      1292954 non-null  float64
#  3   timestamp   1292954 non-null  datetime64[ns]
#  4   model_attr  1292954 non-null  object
#  5   category    1292954 non-null  object
#  6   brand       331120 non-null   object
#  7   year        1292954 non-null  int32
# dtypes: datetime64[ns](1), float64(1), int32(1), int64(2), object(3)
# memory usage: 74.0+ MB

# %%
dataseti['item_id'].nunique() # kemi 9560 lloje produktesh te shitura
# Out:
# 9560

# %%
dataseti['user_id'].nunique() # nr i klieneteve
# Out:
# 1157633

# %%
dataseti['user_id']= dataseti['user_id'].astype(str)
dataseti['item_id']= dataseti['item_id'].astype(str)

# %%
dataseti.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1292954 entries, 0 to 1292953
# Data columns (total 8 columns):
#  #   Column      Non-Null Count    Dtype
# ---  ------      --------------    -----
#  0   item_id     1292954 non-null  object
#  1   user_id     1292954 non-null  object
#  2   rating      1292954 non-null  float64
#  3   timestamp   1292954 non-null  datetime64[ns]
#  4   model_attr  1292954 non-null  object
#  5   category    1292954 non-null  object
#  6   brand       331120 non-null   object
#  7   year        1292954 non-null  int32
# dtypes: datetime64[ns](1), float64(1), int32(1), object(5)
# memory usage: 74.0+ MB

# %%
dataseti.describe()
# Out:
#              rating                      timestamp          year
# count  1.292954e+06                        1292954  1.292954e+06
# mean   4.051482e+00  2015-06-18 11:30:34.851355904  2.014977e+03
# min    1.000000e+00            1999-06-13 00:00:00  1.999000e+03
# 25%    4.000000e+00            2014-09-06 00:00:00  2.014000e+03
# 50%    5.000000e+00            2015-10-19 00:00:00  2.015000e+03
# 75%    5.000000e+00            2016-10-19 00:00:00  2.016000e+03
# max    5.000000e+00            2018-10-01 00:00:00  2.018000e+03
# std    1.379732e+00                            NaN  2.117867e+00

# %%
# Vizualizime
# grafiku i frekuences se rating

sb.countplot(x='rating', data=dataseti)
# Out:
# <Axes: xlabel='rating', ylabel='count'>

# %%
# bejme vizualizimin e viteve
dataseti.groupby('year')['rating'].count().plot(kind='bar')
# Out:
# <Axes: xlabel='year'>

# %%
new_dataset = dataseti[((dataseti['year']==2014) | (dataseti['year']==2015) | (dataseti['year']==2016) | (dataseti['year']==2017))]

# %%
new_dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 996659 entries, 216066 to 1212724
# Data columns (total 8 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   item_id     996659 non-null  object
#  1   user_id     996659 non-null  object
#  2   rating      996659 non-null  float64
#  3   timestamp   996659 non-null  datetime64[ns]
#  4   model_attr  996659 non-null  object
#  5   category    996659 non-null  object
#  6   brand       232725 non-null  object
#  7   year        996659 non-null  int32
# dtypes: datetime64[ns](1), float64(1), int32(1), object(5)
# memory usage: 64.6+ MB

# %%
# bej vizualizimin e category
new_dataset.groupby('category')['rating'].count().plot(kind='bar')
# Out:
# <Axes: xlabel='category'>

# %%
# ndertoj grafik per brand product
new_dataset.groupby('brand')['rating'].count().plot(kind='bar')
# Out:
# <Axes: xlabel='brand'>

# %%
# grafikun me siper e bejme me te qarte, duke marre me pak brand, me te shiturat
new_dataset.groupby('brand')['rating'].count().sort_values(ascending=False).head(14).plot(kind='bar')
# Out:
# <Axes: xlabel='brand'>

# %%
# grafikun me siper e bejme me te qarte, duke marre me pak brand, me pak te shiturat
new_dataset.groupby('brand')['rating'].count().sort_values().head(10).plot(kind='bar')
# Out:
# <Axes: xlabel='brand'>

# %%
# paraqes grafikun e muajve
new_dataset['month'] = pd.DatetimeIndex(new_dataset['timestamp']).month
new_dataset.head()
# Out:
# C:\Users\esoft\AppData\Local\Temp\ipykernel_12944\2312028094.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_dataset['month'] = pd.DatetimeIndex(new_dataset['timestamp']).month
#        item_id user_id  rating  timestamp   model_attr  \
# 216066    1372  203363     4.0 2014-01-01         Male
# 216067    1372  170153     2.0 2014-01-01         Male
# 216068    1397  203364     5.0 2014-01-01         Male
# 216069    3101  203365     5.0 2014-01-01         Male
# 216070    3218  203366     1.0 2014-01-01  Female&Male
#
#                        category brand  year  month
# 216066               Headphones   NaN  2014      1
# 216067               Headphones   NaN  2014      1
# 216068               Headphones   NaN  2014      1
# ...

# %%
new_dataset.groupby('month')['rating'].count().plot(kind='bar')
# Out:
# <Axes: xlabel='month'>

# %%
new_dataset.groupby('brand')['rating'].count().sort_values(ascending=False).head(5).plot(kind='pie', autopct='%1.1f%%', shadow=True)
# Out:
# <Axes: ylabel='rating'>

# %%
new_dataset.groupby('category')['rating'].count().sort_values(ascending=True).head().plot(kind='pie', autopct='%1.1f%%', shadow=True)
# Out:
# <Axes: ylabel='rating'>
