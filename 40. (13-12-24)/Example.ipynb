# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.array([2, 3, 4, 5, 6, 7, 7, 8, 9, 11, 12])
y = np.array([18, 16, 15, 17, 20, 23, 25, 28, 31, 30, 29])

plt.scatter(x, y)

# %%
from sklearn.preprocessing import PolynomialFeatures
from sklearn.linear_model import LinearRegression
# degree =3 
poly = PolynomialFeatures(degree=3, include_bias=False)

poly_trans_features = poly.fit_transform(x.reshape(-1,1))

# %%
poly_reg_model = LinearRegression()
poly_reg_model.fit(poly_trans_features, y)
# Out:
# LinearRegression()

# %%
poly_reg_model.intercept_
# Out:
# 33.626400375322774

# %%
poly_reg_model.coef_
# Out:
# array([-11.83877127,   2.25592957,  -0.10889554])

# %%
y = 33.626400375322774 -11.83877127*x +  2.25592957*x2 -0.10889554 *x3

# %%
y = 33.626400375322774 -11.83877127*2 +  2.25592957*4 -0.10889554 *8
y
# Out:
# 18.101411795322775

# %%
x = np.array([2])

x_tran = poly.fit_transform(x.reshape(-1,1))
y_pred = poly_reg_model.predict(x_tran)
y_pred
# Out:
# array([18.10141176])

# %%
y_pred = poly_reg_model.predict(poly_trans_features)

# %%
plt.scatter(x,y)
plt.plot(x, y_pred, color = 'red')
