# %%
import pandas as pd
data = pd.read_csv("nba.csv")

# %%
data.head()
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2   John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3    R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4  Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
#
#              College     Salary
# 0              Texas  7730337.0
# 1          Marquette  6796117.0
# 2  Boston University        NaN
# 3      Georgia State  1148640.0
# 4                NaN  5000000.0

# %%
# metoda at/iat
name_4 = data.at[4,"Name"]
name_4
# Out:
# 'Jonas Jerebko'

# %%
name_4 = data.iat[4,0]
name_4
# Out:
# 'Jonas Jerebko'

# %%
row3= data.loc[3]
row3
# Out:
# Name           R.J. Hunter
# Team        Boston Celtics
# Number                28.0
# Position                SG
# Age                   22.0
# Height                 6-5
# Weight               185.0
# College      Georgia State
# Salary           1148640.0
# Name: 3, dtype: object

# %%
row1_3 = data.loc[1:3]
row1_3
# Out:
#            Name            Team  Number Position   Age Height  Weight  \
# 1   Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2  John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3   R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
#
#              College     Salary
# 1          Marquette  6796117.0
# 2  Boston University        NaN
# 3      Georgia State  1148640.0

# %%
row1_3 = data.loc[1:3, ['Name', 'Team']]
row1_3
# Out:
#            Name            Team
# 1   Jae Crowder  Boston Celtics
# 2  John Holland  Boston Celtics
# 3   R.J. Hunter  Boston Celtics

# %%
row1_3 = data.iloc[1:3, [0, 1]]
row1_3
# Out:
#            Name            Team
# 1   Jae Crowder  Boston Celtics
# 2  John Holland  Boston Celtics

# %%
# mund te vendosim nje index per dataset qe ne fillim sapo hapim file
data1= pd.read_csv("nba.csv", index_col="Name")
data1.head()
# Out:
#                          Team  Number Position   Age Height  Weight  \
# Name
# Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# Jae Crowder    Boston Celtics    99.0       SF  25.0    6-6   235.0
# John Holland   Boston Celtics    30.0       SG  27.0    6-5   205.0
# R.J. Hunter    Boston Celtics    28.0       SG  22.0    6-5   185.0
# Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
#
#                          College     Salary
# Name
# Avery Bradley              Texas  7730337.0
# Jae Crowder            Marquette  6796117.0
# John Holland   Boston University        NaN
# R.J. Hunter        Georgia State  1148640.0
# Jonas Jerebko                NaN  5000000.0

# %%
data1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 458 entries, Avery Bradley to nan
# Data columns (total 8 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Team      457 non-null    object
#  1   Number    457 non-null    float64
#  2   Position  457 non-null    object
#  3   Age       457 non-null    float64
#  4   Height    457 non-null    object
#  5   Weight    457 non-null    float64
#  6   College   373 non-null    object
#  7   Salary    446 non-null    float64
# dtypes: float64(4), object(4)
# memory usage: 32.2+ KB

# %%
data1.loc['R.J. Hunter', 'Number']
# Out:
# 28.0

# %%
# Merge
data1 = data.head()
data2 = data.tail()

# %%
merge_12= pd.merge(data1, data2, how='outer')
merge_12
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2   John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3    R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4  Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
# 5   Shelvin Mack       Utah Jazz     8.0       PG  26.0    6-3   203.0
# 6      Raul Neto       Utah Jazz    25.0       PG  24.0    6-1   179.0
# 7   Tibor Pleiss       Utah Jazz    21.0        C  26.0    7-3   256.0
# 8    Jeff Withey       Utah Jazz    24.0        C  26.0    7-0   231.0
# 9            NaN             NaN     NaN      NaN   NaN    NaN     NaN
#
#              College     Salary
# 0              Texas  7730337.0
# 1          Marquette  6796117.0
# 2  Boston University        NaN
# 3      Georgia State  1148640.0
# ...

# %%
rresht_ri = {'Name': 'R.J. Hunter', 'Team': 'Boston Celtics', 'Number': 28, "Position": 'SG', 'Age': 22, 
             'Height': '6-5',
             'Weight': 185.0,
             'College': 'Georgia State',
             'Salary': 1148640.0}

# %%
new_row = pd.DataFrame(rresht_ri, index=[0])

# %%
new_row
# Out:
#           Name            Team  Number Position  Age Height  Weight  \
# 0  R.J. Hunter  Boston Celtics      28       SG   22    6-5   185.0
#
#          College     Salary
# 0  Georgia State  1148640.0

# %%
data.head()
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2   John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3    R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4  Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
#
#              College     Salary
# 0              Texas  7730337.0
# 1          Marquette  6796117.0
# 2  Boston University        NaN
# 3      Georgia State  1148640.0
# 4                NaN  5000000.0

# %%
data = pd.concat([new_row, data]).reset_index(drop=True)
data.head()
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 0    R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 1  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 2    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 3   John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 4    R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
#
#              College     Salary
# 0      Georgia State  1148640.0
# 1              Texas  7730337.0
# 2          Marquette  6796117.0
# 3  Boston University        NaN
# 4      Georgia State  1148640.0

# %%
# group by
post_pg = data[data['Position']=='PG']
post_pg
# Out:
#               Name                    Team  Number Position   Age Height  \
# 1    Avery Bradley          Boston Celtics     0.0       PG  25.0    6-2
# 9     Terry Rozier          Boston Celtics    12.0       PG  22.0    6-2
# 10    Marcus Smart          Boston Celtics    36.0       PG  22.0    6-4
# 12   Isaiah Thomas          Boston Celtics     4.0       PG  27.0    5-9
# 20    Jarrett Jack           Brooklyn Nets     2.0       PG  32.0    6-3
# ..             ...                     ...     ...      ...   ...    ...
# 441  Brian Roberts  Portland Trail Blazers     2.0       PG  30.0    6-1
# 444     Trey Burke               Utah Jazz     3.0       PG  23.0    6-1
# 446     Dante Exum               Utah Jazz    11.0       PG  20.0    6-6
# 454   Shelvin Mack               Utah Jazz     8.0       PG  26.0    6-3
# 455      Raul Neto               Utah Jazz    25.0       PG  24.0    6-1
#
#      Weight         College     Salary
# 1     180.0           Texas  7730337.0
# ...

# %%
group_post = data.groupby(['Position'])

# %%
post_pg=group_post.get_group('PG')
post_pg.count()
post_pg
# Out:
#               Name                    Team  Number Position   Age Height  \
# 1    Avery Bradley          Boston Celtics     0.0       PG  25.0    6-2
# 9     Terry Rozier          Boston Celtics    12.0       PG  22.0    6-2
# 10    Marcus Smart          Boston Celtics    36.0       PG  22.0    6-4
# 12   Isaiah Thomas          Boston Celtics     4.0       PG  27.0    5-9
# 20    Jarrett Jack           Brooklyn Nets     2.0       PG  32.0    6-3
# ..             ...                     ...     ...      ...   ...    ...
# 441  Brian Roberts  Portland Trail Blazers     2.0       PG  30.0    6-1
# 444     Trey Burke               Utah Jazz     3.0       PG  23.0    6-1
# 446     Dante Exum               Utah Jazz    11.0       PG  20.0    6-6
# 454   Shelvin Mack               Utah Jazz     8.0       PG  26.0    6-3
# 455      Raul Neto               Utah Jazz    25.0       PG  24.0    6-1
#
#      Weight         College     Salary
# 1     180.0           Texas  7730337.0
# ...

# %%
post_pg.to_csv("pgposition.csv")

# %%
data_pg = pd.read_csv("pgposition.csv").reset_index(drop=True)
data_pg
# Out:
#     Unnamed: 0           Name                    Team  Number Position   Age  \
# 0            1  Avery Bradley          Boston Celtics     0.0       PG  25.0
# 1            9   Terry Rozier          Boston Celtics    12.0       PG  22.0
# 2           10   Marcus Smart          Boston Celtics    36.0       PG  22.0
# 3           12  Isaiah Thomas          Boston Celtics     4.0       PG  27.0
# 4           20   Jarrett Jack           Brooklyn Nets     2.0       PG  32.0
# ..         ...            ...                     ...     ...      ...   ...
# 87         441  Brian Roberts  Portland Trail Blazers     2.0       PG  30.0
# 88         444     Trey Burke               Utah Jazz     3.0       PG  23.0
# 89         446     Dante Exum               Utah Jazz    11.0       PG  20.0
# 90         454   Shelvin Mack               Utah Jazz     8.0       PG  26.0
# 91         455      Raul Neto               Utah Jazz    25.0       PG  24.0
#
#    Height  Weight         College     Salary
# ...

# %%
# heq kolonen index te padeshiruar
data_pg.drop("Unnamed: 0", axis='columns', inplace=True)
data_pg.head()
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1   Terry Rozier  Boston Celtics    12.0       PG  22.0    6-2   190.0
# 2   Marcus Smart  Boston Celtics    36.0       PG  22.0    6-4   220.0
# 3  Isaiah Thomas  Boston Celtics     4.0       PG  27.0    5-9   185.0
# 4   Jarrett Jack   Brooklyn Nets     2.0       PG  32.0    6-3   200.0
#
#           College     Salary
# 0           Texas  7730337.0
# 1      Louisville  1824360.0
# 2  Oklahoma State  3431040.0
# 3      Washington  6912869.0
# 4    Georgia Tech  6300000.0
